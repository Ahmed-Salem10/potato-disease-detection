# %%
import tensorflow as tf 
import numpy as np 
import matplotlib.pyplot as plt
from tensorflow.keras import models,layers

# %%
import os 
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\LOQ\Deep project
# ['.ipynb_checkpoints', 'PlantVillage', 'Untitled.ipynb', 'Untitled1.ipynb']

# %%
dataset=tf.keras.preprocessing.image_dataset_from_directory(
    "PlantVillage",
    shuffle=True,
    batch_size=32,
    class_names=["Potato___healthy",'Potato___Late_blight','Potato___Early_blight'],
    image_size=(256,256)                          
                                                   )
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_names=dataset.class_names
class_names
# Out:
# ['Potato___healthy', 'Potato___Late_blight', 'Potato___Early_blight']

# %%
len(dataset)
# Out:
# 68

# %%
68*32
# Out:
# 2176

# %%
plt.figure(figsize=(10,10))
for image_batch,label_batch in dataset.take(1):
    #print(image_batch.shape)
    #print(label_batch.numpy())
    #print(image_batch[0].numpy())
    for i in range(12):
       ax =plt.subplot(3,4,i+1)
       plt.imshow(image_batch[i].numpy().astype("uint8"))
       plt.title(class_names[label_batch[i]])

# %%
len(dataset)
train_size=.8
len(dataset)*train_size
# Out:
# 54.400000000000006

# %%
train_ds=dataset.take(54)
len(train_ds)
test_ds=dataset.skip(54)
len(test_ds)
# Out:
# 14

# %%
val_size=.1
len(dataset)*val_size
# Out:
# 6.800000000000001

# %%
test_ds=test_ds.skip(6)
len(test_ds)
# Out:
# 8

# %%
def get_dataset_partitions(ds,train_split=.8,test_split=.1,val_split=.1,shuffle=True):
    ds_size=len(ds)
    train_size=int(train_split*ds_size)
    val_size=int(val_split*ds_size)
    train_ds=ds.take(train_size)
    val_ds=ds.skip(train_size).take(val_size)
    test_ds=ds.skip(train_size).skip(val_size)
    return train_ds,val_ds,test_ds

# %%
train_ds,val_ds,test_ds=get_dataset_partitions(dataset)
len(train_ds)
# Out:
# 54

# %%
train_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds=val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds=test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
IMAGE_SIZE=256

# %%
resize_and_rescale=tf.keras.Sequential([
    tf.keras.layers.Resizing(IMAGE_SIZE,IMAGE_SIZE),
    tf.keras.layers.Rescaling(1.0/255)
    
])

# %%
data_augmentation=tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(.2)
])

# %%
input_shape=(256,256,3)
model=models.Sequential([
    layers.Input(shape=input_shape),
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(32,(3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(3,activation="softmax")

    
])
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 254, 254, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 125, 125, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 60, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       147,520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 277,891 (1.06 MB)
#  Trainable params: 277,891 (1.06 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer="adam",
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=["accuracy"]
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
model.fit(train_ds,epochs=50,validation_data=val_ds,verbose=1)
# Out:
# Epoch 1/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 48s 810ms/step - accuracy: 0.5278 - loss: 0.8765 - val_accuracy: 0.7240 - val_loss: 0.6695
# Epoch 2/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 810ms/step - accuracy: 0.7841 - loss: 0.5392 - val_accuracy: 0.7500 - val_loss: 0.7059
# Epoch 3/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 814ms/step - accuracy: 0.8426 - loss: 0.3553 - val_accuracy: 0.8229 - val_loss: 0.3453
# Epoch 4/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 43s 801ms/step - accuracy: 0.8773 - loss: 0.3035 - val_accuracy: 0.8958 - val_loss: 0.2463
# Epoch 5/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 43s 802ms/step - accuracy: 0.9184 - loss: 0.1998 - val_accuracy: 0.9219 - val_loss: 0.1797
# Epoch 6/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 43s 806ms/step - accuracy: 0.9288 - loss: 0.1808 - val_accuracy: 0.9479 - val_loss: 0.1558
# Epoch 7/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 82s 810ms/step - accuracy: 0.9520 - loss: 0.1263 - val_accuracy: 0.9635 - val_loss: 0.1004
# Epoch 8/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 809ms/step - accuracy: 0.9578 - loss: 0.1327 - val_accuracy: 0.9479 - val_loss: 0.1221
# Epoch 9/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 43s 802ms/step - accuracy: 0.9508 - loss: 0.1361 - val_accuracy: 0.9635 - val_loss: 0.1064
# Epoch 10/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 43s 799ms/step - accuracy: 0.9676 - loss: 0.0984 - val_accuracy: 0.9531 - val_loss: 0.1366
# Epoch 11/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 42s 783ms/step - accuracy: 0.9572 - loss: 0.1095 - val_accuracy: 0.9479 - val_loss: 0.1626
# Epoch 12/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 43s 802ms/step - accuracy: 0.9716 - loss: 0.0751 - val_accuracy: 0.9427 - val_loss: 0.1508
# Epoch 13/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 809ms/step - accuracy: 0.9786 - loss: 0.0583 - val_accuracy: 0.9271 - val_loss: 0.1652
# Epoch 14/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 43s 799ms/step - accuracy: 0.9821 - loss: 0.0567 - val_accuracy: 0.9740 - val_loss: 0.0730
# Epoch 15/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 43s 806ms/step - accuracy: 0.9716 - loss: 0.0772 - val_accuracy: 0.9583 - val_loss: 0.1338
# Epoch 16/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 808ms/step - accuracy: 0.9769 - loss: 0.0589 - val_accuracy: 0.9844 - val_loss: 0.0616
# Epoch 17/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 812ms/step - accuracy: 0.9809 - loss: 0.0467 - val_accuracy: 0.9844 - val_loss: 0.0296
# Epoch 18/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 813ms/step - accuracy: 0.9878 - loss: 0.0345 - val_accuracy: 0.9896 - val_loss: 0.0468
# Epoch 19/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 46s 848ms/step - accuracy: 0.9786 - loss: 0.0567 - val_accuracy: 0.9792 - val_loss: 0.0525
# Epoch 20/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 45s
# Epoch 50/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 807ms/step - accuracy: 0.9959 - loss: 0.0156 - val_accuracy: 0.9948 - val_loss: 0.0212

# %%
scores=model.evaluate(test_ds)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 1.0000 - loss: 0.0060

# %%
scores
# Out:
# [0.005998596083372831, 1.0]

# %%
# %history
# Out:
# import tensorflow as tf
# import numpy as np
# import matplotlib.pyplot as plt
# from tensorflow.keras import models,layers
# import os
# print(os.getcwd())
# print(os.listdir())
# dataset=tf.keras.preprocessing.image_dataset_from_directory(
#     "PlantVillage",
#     shuffle=True,
#     batch_size=32,
#     class_names=["Potato___healthy",'Potato___Late_blight','Potato___Early_blight'],
#     image_size=(256,256)
#                                                    )
# class_names=dataset.class_names
# class_names
# len(dataset)
# 68*32
# plt.figure(figsize=(10,10))
# for image_batch,label_batch in dataset.take(1):
#     #print(image_batch.shape)
#     #print(label_batch.numpy())
#     #print(image_batch[0].numpy())
#     for i in range(12):
#        ax =plt.subplot(3,4,i+1)
#        plt.imshow(image_batch[i].numpy().astype("uint8"))
#        plt.title(class_names[label_batch[i]])
# len(dataset)
# train_size=.8
# len(dataset)*train_size
# train_ds=dataset.take(54)
# len(train_ds)
# test_ds=dataset.skip(54)
# len(test_ds)
# val_size=.1
# len(dataset)*val_size
# test_ds=test_ds.skip(6)
# len(test_ds)
# def get_dataset_partitions(ds,train_split=.8,test_split=.1,val_split=.1,shuffle=True):
#     ds_size=len(ds)
#     train_size=int(train_split*ds_size)
#     val_size=int(val_split*ds_size)
#     train_ds=ds.take(train_size)
#     val_ds=ds.skip(train_size).take(val_size)
#     test_ds=ds.skip(train_size).skip(val_size)
#     return train_ds,val_ds,test_ds
# train_ds,val_ds,test_ds=get_dataset_partitions(dataset)
# len(train_ds)
# train_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
# val_ds=val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
# test_ds=test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
# IMAGE_SIZE=256
# resize_and_rescale=tf.keras.Sequential([
#     tf.keras.layers.Resizing(IMAGE_SIZE,IMAGE_SIZE),
#     tf.keras.layers.Rescaling(1.0/255)
#
# ])
# data_augmentation=tf.keras.Sequential([
#     tf.keras.layers.RandomFlip("horizontal_and_vertical"),
#     tf.keras.layers.RandomRotation(.2)
# ])
# input_shape=(256,256,3)
# model=models.Sequential([
#     layers.Input(shape=input_shape),
#     resize_and_rescale,
#     data_augmentation,
#     layers.Conv2D(32,(3,3),activation='relu'),
#     layers.MaxPooling2D((2,2)),
#     layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
#     layers.MaxPooling2D((2,2)),
#     layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
#     layers.MaxPooling2D((2,2)),
#     layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
#     layers.MaxPooling2D((2,2)),
#     layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
#     layers.MaxPooling2D((2,2)),
#     layers.Flatten(),
#     layers.Dense(64,activation='relu'),
#     layers.Dense(3,activation="softmax")
#
#
# ])
# model.summary()
# model.compile(
#     optimizer="adam",
#     loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
#     metrics=["accuracy"]
# )
# model.fit(train_ds,epochs=50,validation_data=val_ds,verbose=1)
# model.evaluate(test_ds)
# scores
# scores=model.evaluate(test_ds)
# scores
# %history

# %%
for images_batch,labels_batch in test_ds.take(1):
    first_image=images_batch[0].numpy().astype("uint8")
    first_label=labels_batch[0].numpy()
    print("first image to predict ")
    plt.imshow(first_image)
    print("first image actual label",class_names[first_label])
    batch_prediction=model.predict(images_batch)
    print("predicted label :",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# first image actual label Potato___Late_blight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# predicted label : Potato___Late_blight

# %%
def predict (model,img):
    img_array=tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array=tf.expand_dims(img_array,0)
    predictions=model.predict(img_array)
    predicted_class=class_names[np.argmax(predictions[0])]
    confidence=round(100*(np.max(predictions[0])),2)
    return predicted_class,confidence

# %%
plt.figure(figsize=(15,15))
for images,labels in test_ds.take(1):
    for i in range(9):
        ax=plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        predicted_class,confidence=predict(model,images[i].numpy())
        actual_class=class_names[labels[i]]
        plt.title(f"Actual:{actual_class},\n predicted: {predicted_class},\n Confidence {confidence}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step

# %%
model_version=1
model.save(f"../models/{model_version}.keras")

# %%
model.export(f"../models/{model_version}")
# Out:
# INFO:tensorflow:Assets written to: ../models/1\assets
# INFO:tensorflow:Assets written to: ../models/1\assets
# Saved artifact at '../models/1'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   2563278728336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2563278721232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2563278717008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2563278731408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2563278731024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2563278731216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2563278730256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2563278731792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2563278731600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2563278732176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2563278732752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2563278732368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2563278732944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2563278733136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2563278732560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2563274589392: TensorSpec(shape=(), dtype=tf.resource, name=None)
